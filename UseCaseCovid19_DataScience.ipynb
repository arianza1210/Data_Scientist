# %% [markdown]
# <a href="https://colab.research.google.com/github/arianza1210/Data_Analyst/blob/main/UseCaseCovid19_DataScience.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# UseCase Covid 19

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# DATA PREPARATION

# %%
df=pd.read_csv('/content/drive/MyDrive/Dataset/owid-covid-data.csv')

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
# [5 rows x 59 columns]

# %%
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 73991      ZWE    Africa     Zimbabwe  2021-03-06      36260.0       12.0
# 73992      ZWE    Africa     Zimbabwe  2021-03-07      36271.0       11.0
# 73993      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 73994      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 73995      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 73991              28.857        1485.0         1.0                3.143  ...
# 73992              26.000        1485.0         0.0                3.143  ...
# 73993              24.857        1487.0         2.0                2.714  ...
# 73994              24.714        1489.0         2.0                2.429  ...
# 73995              23.143        1489.0         0.0                1.571  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 73991        1899.775             21.4                307.846
# 73992        1899.775             21.4                307.846
# 73993        1899.775             21.4                307.846
# 73994        1899.775             21.4                307.846
# 73995        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 73991                 1.82             1.6          30.7
# 73992                 1.82             1.6          30.7
# 73993                 1.82             1.6          30.7
# 73994                 1.82             1.6          30.7
# 73995                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 73991                  36.791                         1.7            61.49
# 73992                  36.791                         1.7            61.49
# 73993                  36.791                         1.7            61.49
# 73994                  36.791                         1.7            61.49
# 73995                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 73991                    0.571
# 73992                    0.571
# 73993                    0.571
# 73994                    0.571
# 73995                    0.571
#
# [73996 rows x 59 columns]

# %%
df.shape
# Out:
# (73996, 59)

# %%
print(df['location'].value_counts())
# Out:
# Argentina           435
# Mexico              435
# Thailand            432
# Taiwan              420
# South Korea         415
#                    ...
# Falkland Islands     16
# Montserrat           16
# Macao                11
# Northern Cyprus       9
# Saint Helena          1
# Name: location, Length: 215, dtype: int64

# %% [markdown]
# DATA CLEANSING

# %%
df_ina=df.loc[df['location']=='Indonesia']

# %%
#reset index
df_ina=df_ina.reset_index(drop=True)

# %%
df_ina.head()
# Out:
#   iso_code continent   location        date  total_cases  new_cases  \
# 0      IDN      Asia  Indonesia  2020-03-02          2.0        2.0
# 1      IDN      Asia  Indonesia  2020-03-03          2.0        0.0
# 2      IDN      Asia  Indonesia  2020-03-04          2.0        0.0
# 3      IDN      Asia  Indonesia  2020-03-05          2.0        0.0
# 4      IDN      Asia  Indonesia  2020-03-06          4.0        2.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0       11188.744              5.7                342.864
# 1       11188.744              5.7                342.864
# 2       11188.744              5.7                342.864
# 3       11188.744              5.7                342.864
# 4       11188.744              5.7                342.864
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 6.32             2.8          76.1                  64.204
# 1                 6.32             2.8          76.1                  64.204
# 2                 6.32             2.8          76.1                  64.204
# 3                 6.32             2.8          76.1                  64.204
# 4                 6.32             2.8          76.1                  64.204
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                        1.04            71.72                    0.718
# 1                        1.04            71.72                    0.718
# 2                        1.04            71.72                    0.718
# 3                        1.04            71.72                    0.718
# 4                        1.04            71.72                    0.718
#
# [5 rows x 59 columns]

# %%
df_ina.tail()
# Out:
#     iso_code continent   location        date  total_cases  new_cases  \
# 369      IDN      Asia  Indonesia  2021-03-06    1373836.0     5767.0
# 370      IDN      Asia  Indonesia  2021-03-07    1379662.0     5826.0
# 371      IDN      Asia  Indonesia  2021-03-08    1386556.0     6894.0
# 372      IDN      Asia  Indonesia  2021-03-09    1392945.0     6389.0
# 373      IDN      Asia  Indonesia  2021-03-10    1398578.0     5633.0
#
#      new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 369            6394.571       37154.0       128.0              167.571  ...
# 370            6432.571       37266.0       112.0              157.143  ...
# 371            6463.143       37547.0       281.0              174.571  ...
# 372            6559.857       37757.0       210.0              177.000  ...
# 373            6392.000       37932.0       175.0              173.000  ...
#
#      gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 369       11188.744              5.7                342.864
# 370       11188.744              5.7                342.864
# 371       11188.744              5.7                342.864
# 372       11188.744              5.7                342.864
# 373       11188.744              5.7                342.864
#
#      diabetes_prevalence  female_smokers  male_smokers  \
# 369                 6.32             2.8          76.1
# 370                 6.32             2.8          76.1
# 371                 6.32             2.8          76.1
# 372                 6.32             2.8          76.1
# 373                 6.32             2.8          76.1
#
#      handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 369                  64.204                        1.04            71.72
# 370                  64.204                        1.04            71.72
# 371                  64.204                        1.04            71.72
# 372                  64.204                        1.04            71.72
# 373                  64.204                        1.04            71.72
#
#      human_development_index
# 369                    0.718
# 370                    0.718
# 371                    0.718
# 372                    0.718
# 373                    0.718
#
# [5 rows x 59 columns]

# %%
df_ina.shape
# Out:
# (374, 59)

# %%
df_ina.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'new_vaccinations',
#        'new_vaccinations_smoothed', 'total_vaccinations_per_hundred',
#        'people_vaccinated_per_hundred', 'people_fully_vaccinated_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index'],
#       dtype='object')

# %%
df_ina=df_ina[['date','total_cases','new_cases','total_deaths','new_deaths']]

# %%
df_ina
# Out:
#            date  total_cases  new_cases  total_deaths  new_deaths
# 0    2020-03-02          2.0        2.0           NaN         NaN
# 1    2020-03-03          2.0        0.0           NaN         NaN
# 2    2020-03-04          2.0        0.0           NaN         NaN
# 3    2020-03-05          2.0        0.0           NaN         NaN
# 4    2020-03-06          4.0        2.0           NaN         NaN
# ..          ...          ...        ...           ...         ...
# 369  2021-03-06    1373836.0     5767.0       37154.0       128.0
# 370  2021-03-07    1379662.0     5826.0       37266.0       112.0
# 371  2021-03-08    1386556.0     6894.0       37547.0       281.0
# 372  2021-03-09    1392945.0     6389.0       37757.0       210.0
# 373  2021-03-10    1398578.0     5633.0       37932.0       175.0
#
# [374 rows x 5 columns]

# %%
#ubah data NaN jadi 0
df_ina=df_ina.fillna(0)

# %%
df_ina
# Out:
#            date  total_cases  new_cases  total_deaths  new_deaths
# 0    2020-03-02          2.0        2.0           0.0         0.0
# 1    2020-03-03          2.0        0.0           0.0         0.0
# 2    2020-03-04          2.0        0.0           0.0         0.0
# 3    2020-03-05          2.0        0.0           0.0         0.0
# 4    2020-03-06          4.0        2.0           0.0         0.0
# ..          ...          ...        ...           ...         ...
# 369  2021-03-06    1373836.0     5767.0       37154.0       128.0
# 370  2021-03-07    1379662.0     5826.0       37266.0       112.0
# 371  2021-03-08    1386556.0     6894.0       37547.0       281.0
# 372  2021-03-09    1392945.0     6389.0       37757.0       210.0
# 373  2021-03-10    1398578.0     5633.0       37932.0       175.0
#
# [374 rows x 5 columns]

# %% [markdown]
# **Exploration Data Analyzing (EDA)**
# Tahapan memahami isi data:
#
#
# 1.   Univariat Analysis
# 2.   Bivariat Analysis
#
# 1.   Multivariat Analysis

# %%
df_ina['new_cases'].plot(label='Kasus Baru')
df_ina['new_deaths'].plot(label='Kasus Kematian')
plt.xlabel('Hari ke-')
plt.ylabel('Kasus per hari')
plt.legend(loc='best')
plt.show()

# %%
for i in range(len(df_ina)):
  if df_ina['new_cases'].iloc[i]==df_ina['new_cases'].max():
    print('tanggal kasus positif tertinggi {}'.format(df_ina['date'].iloc[i]))
    print('Dengan Jumlah = {} '.format(df_ina['new_cases'].iloc[i]))
    break
# Out:
# tanggal kasus positif tertinggi 2021-01-30
# Dengan Jumlah = 14518.0

# %%
df_ina['total_cases'].plot(label='Positif')
df_ina['total_deaths'].plot(label='Kematian')
plt.xlabel('Hari Ke-')
plt.ylabel('Jumlah Kasus Kumulatif per Hari')
plt.legend(loc='best')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# **Model Prediksi**

# %%
def kurva_sigmoid(t,a,t0,c):
   return c/(1+np.exp(-(t-t0)/(a)))

# %%
x=list(df_ina.index)
y=list(df_ina['total_cases'])

# %%
from scipy.optimize import curve_fit, fsolve

# %%
fit=curve_fit(kurva_sigmoid,x,y,method='trf')
varA,varB=fit

# %%
varA
# Out:
# array([6.91350214e+01, 3.71790857e+02, 2.84763171e+06])

# %%
varB
# Out:
# array([[5.78360266e-01, 2.65323681e+00, 5.86834658e+04],
#        [2.65323681e+00, 1.35936193e+01, 3.06836336e+05],
#        [5.86834658e+04, 3.06836336e+05, 6.98107781e+09]])

# %%
std_er=np.zeros(len(varA))
for i in range(len(varA)):
  std_er[i]=np.sqrt(varB[i][i])

# %%
std_er
# Out:
# array([7.60500011e-01, 3.68695257e+00, 8.35528444e+04])

# %%
a=varA[0]+std_er[0]
t0=varA[1]+std_er[1]
c=varA[2]+std_er[2]

# %%
def puncak(x):
  return kurva_sigmoid(x,a,t0,c)-int(c)

# %%
n_puncak=int(fsolve(puncak,t0))

# %%
print('Hari puncak Wabah covid-19 adalah hari Ke-'+str(n_puncak))
# Out:
# Hari puncak Wabah covid-19 adalah hari Ke-1458

# %% [markdown]
# Analisis Data

# %%
n_0=max(x)+1
pred_x=list(range(n_0,n_puncak))

# %%
print('kita memiliki {} hari menuju puncak wabah'.format(str(len(pred_x))))
# Out:
# kita memiliki 1084 hari menuju puncak wabah

# %%
pred_y=np.zeros(len(x+pred_x))
for i in range(n_puncak):
  pred_y[i]=kurva_sigmoid(i,a,t0,c)

# %%
print('Prediksi Jumlah Puncak {} orang'.format(int(pred_y[-1])))
# Out:
# Prediksi Jumlah Puncak 2931183 orang

# %%
plt.plot(x+pred_x,pred_y,label="Prediksi")
plt.scatter(x,y,label='Data Asli', s=10,color='red')
plt.xlabel('Hari Ke-')
plt.ylabel=('Jumlah Kumulatif kasus positif')
plt.grid()
plt.legend(loc='best')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# **Akurasi**

# %%
def akurasi_r2(y_asli,y_prediksi,x):
  atas=sum((y_asli-y_prediksi[0:len(x)]))**2
  bawah=sum((y_asli-np.mean(y))**2)
  r=1-(atas/bawah)
  return r

# %%
akur=akurasi_r2(y,pred_y,x)

# %%
akur*100
# Out:
# 94.58612643674313

# %%
from datetime import datetime, timedelta

# %%
df
# Out:
#       iso_code continent     location        date  total_cases  new_cases  \
# 0          AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1          AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2          AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3          AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4          AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
# ...        ...       ...          ...         ...          ...        ...
# 73991      ZWE    Africa     Zimbabwe  2021-03-06      36260.0       12.0
# 73992      ZWE    Africa     Zimbabwe  2021-03-07      36271.0       11.0
# 73993      ZWE    Africa     Zimbabwe  2021-03-08      36289.0       18.0
# 73994      ZWE    Africa     Zimbabwe  2021-03-09      36321.0       32.0
# 73995      ZWE    Africa     Zimbabwe  2021-03-10      36341.0       20.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                     NaN           NaN         NaN                  NaN  ...
# 1                     NaN           NaN         NaN                  NaN  ...
# 2                     NaN           NaN         NaN                  NaN  ...
# 3                     NaN           NaN         NaN                  NaN  ...
# 4                     NaN           NaN         NaN                  NaN  ...
# ...                   ...           ...         ...                  ...  ...
# 73991              28.857        1485.0         1.0                3.143  ...
# 73992              26.000        1485.0         0.0                3.143  ...
# 73993              24.857        1487.0         2.0                2.714  ...
# 73994              24.714        1489.0         2.0                2.429  ...
# 73995              23.143        1489.0         0.0                1.571  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0            1803.987              NaN                597.029
# 1            1803.987              NaN                597.029
# 2            1803.987              NaN                597.029
# 3            1803.987              NaN                597.029
# 4            1803.987              NaN                597.029
# ...               ...              ...                    ...
# 73991        1899.775             21.4                307.846
# 73992        1899.775             21.4                307.846
# 73993        1899.775             21.4                307.846
# 73994        1899.775             21.4                307.846
# 73995        1899.775             21.4                307.846
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.59             NaN           NaN
# 1                     9.59             NaN           NaN
# 2                     9.59             NaN           NaN
# 3                     9.59             NaN           NaN
# 4                     9.59             NaN           NaN
# ...                    ...             ...           ...
# 73991                 1.82             1.6          30.7
# 73992                 1.82             1.6          30.7
# 73993                 1.82             1.6          30.7
# 73994                 1.82             1.6          30.7
# 73995                 1.82             1.6          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                      37.746                         0.5            64.83
# 1                      37.746                         0.5            64.83
# 2                      37.746                         0.5            64.83
# 3                      37.746                         0.5            64.83
# 4                      37.746                         0.5            64.83
# ...                       ...                         ...              ...
# 73991                  36.791                         1.7            61.49
# 73992                  36.791                         1.7            61.49
# 73993                  36.791                         1.7            61.49
# 73994                  36.791                         1.7            61.49
# 73995                  36.791                         1.7            61.49
#
#        human_development_index
# 0                        0.511
# 1                        0.511
# 2                        0.511
# 3                        0.511
# 4                        0.511
# ...                        ...
# 73991                    0.571
# 73992                    0.571
# 73993                    0.571
# 73994                    0.571
# 73995                    0.571
#
# [73996 rows x 59 columns]

# %%
df_ina
# Out:
#            date  total_cases  new_cases  total_deaths  new_deaths
# 0    2020-03-02          2.0        2.0           0.0         0.0
# 1    2020-03-03          2.0        0.0           0.0         0.0
# 2    2020-03-04          2.0        0.0           0.0         0.0
# 3    2020-03-05          2.0        0.0           0.0         0.0
# 4    2020-03-06          4.0        2.0           0.0         0.0
# ..          ...          ...        ...           ...         ...
# 369  2021-03-06    1373836.0     5767.0       37154.0       128.0
# 370  2021-03-07    1379662.0     5826.0       37266.0       112.0
# 371  2021-03-08    1386556.0     6894.0       37547.0       281.0
# 372  2021-03-09    1392945.0     6389.0       37757.0       210.0
# 373  2021-03-10    1398578.0     5633.0       37932.0       175.0
#
# [374 rows x 5 columns]

# %%
frmt='%Y-%m-%d'
n1=df_ina['date'][0]
tgl_0=datetime.strptime(n1,frmt)
print(tgl_0)
# Out:
# 2020-03-02 00:00:00

# %%
tgl_puncak=tgl_0+timedelta(days=n_puncak)
print(tgl_puncak)
# Out:
# 2024-02-28 00:00:00

# %%
h_puncak=tgl_puncak.strftime(frmt)

# %%
h_puncak
# Out:
# '2024-02-28'

# %%
df_ina
# Out:
#            date  total_cases  new_cases  total_deaths  new_deaths
# 0    2020-03-02          2.0        2.0           0.0         0.0
# 1    2020-03-03          2.0        0.0           0.0         0.0
# 2    2020-03-04          2.0        0.0           0.0         0.0
# 3    2020-03-05          2.0        0.0           0.0         0.0
# 4    2020-03-06          4.0        2.0           0.0         0.0
# ..          ...          ...        ...           ...         ...
# 369  2021-03-06    1373836.0     5767.0       37154.0       128.0
# 370  2021-03-07    1379662.0     5826.0       37266.0       112.0
# 371  2021-03-08    1386556.0     6894.0       37547.0       281.0
# 372  2021-03-09    1392945.0     6389.0       37757.0       210.0
# 373  2021-03-10    1398578.0     5633.0       37932.0       175.0
#
# [374 rows x 5 columns]

# %%
df_ina['total_pred']=pred_y[0:len(x)].astype(int)
df_ina['selisih']=abs(df_ina['total_pred']-df_ina['total_cases'])

# %%
df_ina
# Out:
#            date  total_cases  new_cases  total_deaths  new_deaths  total_pred  \
# 0    2020-03-02          2.0        2.0           0.0         0.0       13552
# 1    2020-03-03          2.0        0.0           0.0         0.0       13746
# 2    2020-03-04          2.0        0.0           0.0         0.0       13943
# 3    2020-03-05          2.0        0.0           0.0         0.0       14143
# 4    2020-03-06          4.0        2.0           0.0         0.0       14346
# ..          ...          ...        ...           ...         ...         ...
# 369  2021-03-06    1373836.0     5767.0       37154.0       128.0     1397726
# 370  2021-03-07    1379662.0     5826.0       37266.0       112.0     1408191
# 371  2021-03-08    1386556.0     6894.0       37547.0       281.0     1418662
# 372  2021-03-09    1392945.0     6389.0       37757.0       210.0     1429137
# 373  2021-03-10    1398578.0     5633.0       37932.0       175.0     1439617
#
#      selisih
# 0    13550.0
# 1    13744.0
# 2    13941.0
# 3    14141.0
# 4    14342.0
# ..       ...
# 369  23890.0
# 370  28529.0
# 371  32106.0
# 372  36192.0
# 373  41039.0
#
# [374 rows x 7 columns]

# %%
df_ina=df_ina[['date','new_cases','total_deaths','new_deaths','total_cases','total_pred','selisih']]

# %%
df_ina
# Out:
#            date  new_cases  total_deaths  new_deaths  total_cases  total_pred  \
# 0    2020-03-02        2.0           0.0         0.0          2.0       13552
# 1    2020-03-03        0.0           0.0         0.0          2.0       13746
# 2    2020-03-04        0.0           0.0         0.0          2.0       13943
# 3    2020-03-05        0.0           0.0         0.0          2.0       14143
# 4    2020-03-06        2.0           0.0         0.0          4.0       14346
# ..          ...        ...           ...         ...          ...         ...
# 369  2021-03-06     5767.0       37154.0       128.0    1373836.0     1397726
# 370  2021-03-07     5826.0       37266.0       112.0    1379662.0     1408191
# 371  2021-03-08     6894.0       37547.0       281.0    1386556.0     1418662
# 372  2021-03-09     6389.0       37757.0       210.0    1392945.0     1429137
# 373  2021-03-10     5633.0       37932.0       175.0    1398578.0     1439617
#
#      selisih
# 0    13550.0
# 1    13744.0
# 2    13941.0
# 3    14141.0
# 4    14342.0
# ..       ...
# 369  23890.0
# 370  28529.0
# 371  32106.0
# 372  36192.0
# 373  41039.0
#
# [374 rows x 7 columns]

# %%
df_ina.tail(20)
# Out:
#            date  new_cases  total_deaths  new_deaths  total_cases  total_pred  \
# 354  2021-02-19    10614.0       34152.0       183.0    1263299.0     1242170
# 355  2021-02-20     8054.0       34316.0       164.0    1271353.0     1252422
# 356  2021-02-21     7300.0       34489.0       173.0    1278653.0     1262695
# 357  2021-02-22    10180.0       34691.0       202.0    1288833.0     1272988
# 358  2021-02-23     9775.0       35014.0       323.0    1298608.0     1283300
# 359  2021-02-24     7533.0       35254.0       240.0    1306141.0     1293631
# 360  2021-02-25     8493.0       35518.0       264.0    1314634.0     1303980
# 361  2021-02-26     8232.0       35786.0       268.0    1322866.0     1314344
# 362  2021-02-27     6208.0       35981.0       195.0    1329074.0     1324724
# 363  2021-02-28     5560.0       36166.0       185.0    1334634.0     1335119
# 364  2021-03-01     6680.0       36325.0       159.0    1341314.0     1345526
# 365  2021-03-02     5712.0       36518.0       193.0    1347026.0     1355946
# 366  2021-03-03     6808.0       36721.0       203.0    1353834.0     1366377
# 367  2021-03-04     7264.0       36897.0       176.0    1361098.0     1376818
# 368  2021-03-05     6971.0       37026.0       129.0    1368069.0     1387268
# 369  2021-03-06     5767.0       37154.0       128.0    1373836.0     1397726
# 370  2021-03-07     5826.0       37266.0       112.0    1379662.0     1408191
# 371  2021-03-08     6894.0       37547.0       281.0    1386556.0     1418662
# 372  2021-03-09     6389.0       37757.0       210.0    1392945.0     1429137
# 373  2021-03-10     5633.0       37932.0       175.0    1398578.0     1439617
#
#      selisih
# 354  21129.0
# 355  18931.0
# 356  15958.0
# 357  15845.0
# 358  15308.0
# 359  12510.0
# 360  10654.0
# 361   8522.0
# 362   4350.0
# 363    485.0
# 364   4212.0
# 365   8920.0
# 366  12543.0
# 367  15720.0
# 368  19199.0
# 369  23890.0
# 370  28529.0
# 371  32106.0
# 372  36192.0
# 373  41039.0

# %% [markdown]
# Visualisasi data

# %%
label=['Real','Prediksi']
value=[df_ina['total_cases'].iloc[-1],
       df_ina['total_pred'].iloc[-1]]
plt.bar(label,value)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
label=np.array(df_ina['date'].iloc[-10:-1],dtype=str)
value=np.array(df_ina['total_cases'].iloc[-10:-1],dtype=int)
plt.barh(label,value)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
